# %% [markdown]
# <a href="https://colab.research.google.com/github/yang-song/score_sde_pytorch/blob/main/Score_SDE_demo_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparation
#
# 1. `git clone https://github.com/yang-song/score_sde_pytorch.git`
#
# 2. Install [required packages](https://github.com/yang-song/score_sde_pytorch/blob/main/requirements.txt)
#
# 3. `cd` into folder `score_sde_pytorch`, launch a local jupyter server and connect to colab following [these instructions](https://research.google.com/colaboratory/local-runtimes.html)
#
# 4. Download pre-trained [checkpoints](https://drive.google.com/drive/folders/1tFmF_uh57O6lx9ggtZT_5LdonVK2cV-e?usp=sharing) and save them in the `exp` folder.

# %%
import torch
print(torch.cuda.is_available())
print(torch.__version__)
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1.11.0+cu102
# 1
# NVIDIA Tesla V100-SXM2-32GB

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: requests[socks] in /home/nasseraa/.conda/envs/SBGMv2/lib/python3.9/site-packages (from gdown) (2.27.1)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.0-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 65 kB/s  eta 0:00:01
# Requirement already satisfied: six in /home/nasseraa/.conda/envs/SBGMv2/lib/python3.9/site-packages (from gdown) (1.15.0)
# Collecting filelock
#   Downloading filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: tqdm in /home/nasseraa/.conda/envs/SBGMv2/lib/python3.9/site-packages (from gdown) (4.64.0)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nasseraa/.conda/envs/SBGMv2/lib/python3.9/site-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/nasseraa/.conda/envs/SBGMv2/lib/python3.9/site-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/nasseraa/.conda/envs/SBGMv2/lib/python3.9/site-packages (from requests[socks]->gdown) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/nasseraa/.conda/envs/SBGMv2/lib/python3.9/site-packages (from requests[socks]->gdown) (1.26.9)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14775 sha256=2519b0661268c525eeb3b7b824bcd6ebfa43790b6c7d939a360e1741ee62b6f8
#   Stored in directory: /home/nasseraa/.cache/pip/wheels/7d/37/b6/b2a79c75e898c0b8e46ff255102602d7159a10d9af0d80641a
# Successfully built gdown
# Installing collected packages: soupsieve, PySocks, filelock, beautifulsoup4, gdown
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.11.0 filelock-3.6.0 gdown-4.4.0 soupsieve-2.3.2

# %%
import gdown
url = "https://drive.google.com/uc?id=1LxxgVBHWgyN8jzf8bQssgVOrTLE8Gv2v"
output = "ffhq-r08.tfrecords"
gdown.download(url,output,quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LxxgVBHWgyN8jzf8bQssgVOrTLE8Gv2v
# To: /home/nasseraa/research_spring22/SBGM/score_sde_pytorch/ffhq-r08.tfrecords
# 100%|██████████████████████████████████████████████████████████| 13.8G/13.8G [06:05<00:00, 37.7MB/s]
# 'ffhq-r08.tfrecords'

# %%
import gdown
url = "https://drive.google.com/uc?id=1-mtdSwuefIZA0n85QWScQo2WRvJNWwUy"
output = "ffhq256/checkpoints-meta/checkpoint.pth"
gdown.download(url,output,quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-mtdSwuefIZA0n85QWScQo2WRvJNWwUy
# To: /home/nasseraa/research_spring22/SBGM/score_sde_pytorch/ffhq256/checkpoints-meta/checkpoint.pth
# 100%|██████████████████████████████████████████████████████████| 1.05G/1.05G [00:33<00:00, 31.0MB/s]
# 'ffhq256/checkpoints-meta/checkpoint.pth'

# %%
#@title Autoload all modules
# %load_ext autoreload
# %autoreload 2

from dataclasses import dataclass, field
import matplotlib.pyplot as plt
import io
import csv
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import importlib
import os
import functools
import itertools
import torch
from losses import get_optimizer
from models.ema import ExponentialMovingAverage

import torch.nn as nn
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_gan as tfgan
import tqdm
import io
import likelihood
import controllable_generation
from utils import restore_checkpoint
sns.set(font_scale=2)
sns.set(style="whitegrid")

import models
from models import utils as mutils
from models import ncsnv2
from models import ncsnpp
from models import ddpm as ddpm_model
from models import layerspp
from models import layers
from models import normalization
import sampling
from likelihood import get_likelihood_fn
from sde_lib import VESDE, VPSDE, subVPSDE
from sampling import (ReverseDiffusionPredictor, 
                      LangevinCorrector, 
                      EulerMaruyamaPredictor, 
                      AncestralSamplingPredictor, 
                      NoneCorrector, 
                      NonePredictor,
                      AnnealedLangevinDynamics)
import datasets
# Out:
# 2022-05-06 17:08:58.572735: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /home/nasseraa/.conda/envs/SBGMv2/lib/python3.9/site-packages/tensorflow_gan/python/estimator/tpu_gan_estimator.py:42: The name tf.estimator.tpu.TPUEstimator is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimator instead.

# %%
os.getcwd()
# Out:
# '/home/nasseraa/research_spring22/SBGM/score_sde_pytorch'

# %%
os.chdir("/home/nasseraa/research_spring22/SBGM/score_sde_pytorch/")

# %%
# @title Load the score-based model
sde = 'VESDE' #@param ['VESDE', 'VPSDE', 'subVPSDE'] {"type": "string"}
from configs.ve import ffhq_256_ncsnpp_continuous as configs
# ckpt_filename = "/home/nasseraa/research_spring22/SBGM/score_sde_pytorch/exp/ve/ffhq_256_ncsnpp_continuous/checkpoint_48.pth"
ckpt_filename = "/home/nasseraa/research_spring22/SBGM/score_sde_pytorch/ffhq256/checkpoints/checkpoint_4820.pth"
config = configs.get_config()
sde = VESDE(sigma_min=config.model.sigma_min, sigma_max=config.model.sigma_max, N=config.model.num_scales)
sampling_eps = 1e-5

batch_size =   4#@param {"type":"integer"}
config.training.batch_size = batch_size
config.eval.batch_size = batch_size

random_seed = 0 #@param {"type": "integer"}

sigmas = mutils.get_sigmas(config)
scaler = datasets.get_data_scaler(config)
inverse_scaler = datasets.get_data_inverse_scaler(config)
score_model = mutils.create_model(config)

optimizer = get_optimizer(config, score_model.parameters())
ema = ExponentialMovingAverage(score_model.parameters(),
                               decay=config.model.ema_rate)
state = dict(step=0, optimizer=optimizer,
             model=score_model, ema=ema)

state = restore_checkpoint(ckpt_filename, state, config.device)
ema.copy_to(score_model.parameters())

# %%
#@title Visualization code

def image_grid(x):
  size = config.data.image_size
#   size = 1024
  print(size)
  channels = config.data.num_channels
  print(channels)
  img = x.reshape(-1, size, size, channels)
  w = int(np.sqrt(img.shape[0]))
#   w = 4
  print(w)
  img = img.reshape((w, w, size, size, channels)).transpose((0, 2, 1, 3, 4)).reshape((w * size, w * size, channels))
#   img = img.reshape((w, w, size, size, channels)).transpose((4, 0, 2, 1, 3)).reshape((w * size, w * size, channels))
#   img = img.reshape((w, w, size, size, channels)).reshape((w * size, w * size, channels))
  return img

def show_samples(x):
#   x = x.permute(0, 2, 3, 1).detach().cpu().numpy()
  x = x.cpu().numpy()
  img = image_grid(x)
  plt.figure(figsize=(8 ,8))
  plt.axis('off')
  plt.imshow(img)
  plt.show()

# def show_samples(x):
#     x = x.detach().cpu().numpy()
#     plt.subplot(1, 2, 2)
#     plt.axis('off')
#     plt.imshow(image_grid(x))
#     plt.title('Reconstructed images')

# %% [markdown]
# # Predictor Corrector sampling
#
#
# Recommended settings:
#
#  | dataset | SDE | predictor | corrector | snr | n_steps |
# |:----:|:----:|:----------:|:--------:|:---:|:----:|
# |CIFAR-10 | VE | ReverseDiffusionPredictor | LangevinCorrector | 0.16| 1|
# |CIFAR-10 | VP | EulerMaruyamaPredictor | None | - | - |
# |CIFAR-10 | subVP| EulerMaruyamaPredictor | None | - | - |
# | LSUN/CelebA-HQ/FFHQ 256px | VE | ReverseDiffusionPredictor | LangevinCorrector | 0.075 | 1 |
# | FFHQ 1024px | VE | ReverseDiffusionPredictor | LangevinCorrector | 0.15| 1 |
#
# Check `probability_flow` to run PC sampling based on discretizing the probability flow ODE.

# %%
#@title PC sampling
img_size = config.data.image_size
channels = config.data.num_channels
shape = (batch_size, channels, img_size, img_size)
predictor = ReverseDiffusionPredictor #@param ["EulerMaruyamaPredictor", "AncestralSamplingPredictor", "ReverseDiffusionPredictor", "None"] {"type": "raw"}
corrector = LangevinCorrector #@param ["LangevinCorrector", "AnnealedLangevinDynamics", "None"] {"type": "raw"}
snr = 0.075 #@param {"type": "number"}
n_steps =  1#@param {"type": "integer"}
probability_flow = False #@param {"type": "boolean"}
sampling_fn = sampling.get_pc_sampler(sde, shape, predictor, corrector,
                                      inverse_scaler, snr, n_steps=n_steps,
                                      probability_flow=probability_flow,
                                      continuous=config.training.continuous,
                                      eps=sampling_eps, device=config.device)

x, n = sampling_fn(score_model)
show_samples(x)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 256
# 3
# 2

# %% [markdown]
# # Probability flow ODE
#
# With black-box ODE solvers, we can produce samples, compute likelihoods, and obtain a uniquely identifiable encoding of any data point.

# %%
 #@title ODE sampling

shape = (batch_size, 3, 256, 256)
sampling_fn = sampling.get_ode_sampler(sde,                                        
                                       shape, 
                                       inverse_scaler,                                       
                                       denoise=True, 
                                       eps=sampling_eps,
                                       device=config.device)
x, nfe = sampling_fn(score_model)
show_samples(x)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 256
# 3
# 2

# %% [markdown]
# Train the model from a checkpoint

# %%
import logging
import run_lib
os.chdir("/home/nasseraa/research_spring22/SBGM/score_sde_pytorch/ffhq256/")
print(os.getcwd())
# Create the working directory
tf.io.gfile.makedirs('./')
# Set logger so that it outputs to both console and file
# Make logging work for both disk and Google Cloud Storage
gfile_stream = open(os.path.join('./', 'stdout.txt'), 'w')
handler = logging.StreamHandler(gfile_stream)
formatter = logging.Formatter('%(levelname)s - %(filename)s - %(asctime)s - %(message)s')
handler.setFormatter(formatter)
logger = logging.getLogger()
logger.addHandler(handler)
logger.setLevel('INFO')
# Run the training pipeline
run_lib.train(config, './', 20000)
os.chdir("/home/nasseraa/research_spring22/SBGM/score_sde_pytorch/")
# Out:
# /home/nasseraa/research_spring22/SBGM/score_sde_pytorch/ffhq256

# %%
#@title Likelihood computation
train_ds, eval_ds, _ = datasets.get_dataset(config, uniform_dequantization=False, evaluation=True)
eval_iter = iter(eval_ds)
bpds = []
likelihood_fn = likelihood.get_likelihood_fn(sde,                                              
                                             inverse_scaler,                                             
                                             eps=1e-5)
for batch in eval_iter:
  img = batch['image']._numpy()
#   img = torch.tensor(img).permute(0, 3, 1, 2).to(config.device)
  img = torch.tensor(img).to(config.device)
  img = scaler(img)
  bpd, z, nfe = likelihood_fn(score_model, img)
  bpds.extend(bpd)
  print(f"average bpd: {torch.tensor(bpds).mean().item()}, NFE: {nfe}")
# Out:
# average bpd: 2.988525629043579, NFE: 194
# average bpd: 2.8021323680877686, NFE: 182
# average bpd: 2.8003807067871094, NFE: 176
# average bpd: 2.836432933807373, NFE: 152
# average bpd: 2.8758957386016846, NFE: 188
# average bpd: 2.7929975986480713, NFE: 218
# average bpd: 2.796457290649414, NFE: 164
# average bpd: 2.7616031169891357, NFE: 176
# average bpd: 2.7354025840759277, NFE: 170
# average bpd: 2.710280418395996, NFE: 206
# average bpd: 2.658952474594116, NFE: 206
# average bpd: 2.6714398860931396, NFE: 176
# average bpd: 2.662862539291382, NFE: 188
# average bpd: 2.681192398071289, NFE: 158
# average bpd: 2.675168514251709, NFE: 200
# average bpd: 2.658918857574463, NFE: 170
# average bpd: 2.643942356109619, NFE: 206
# average bpd: 2.646658420562744, NFE: 164
# average bpd: 2.644165277481079, NFE: 176
# average bpd: 2.6545987129211426, NFE: 170
# average bpd: 2.664180278778076, NFE: 212
# average bpd: 2.676056146621704, NFE: 164
# average bpd: 2.6715340614318848, NFE: 182
# average bpd: 2.6614978313446045, NFE: 164
# average bpd: 2.66015625, NFE: 158
# average bpd: 2.65690016746521, NFE: 182
# average bpd: 2.6550402641296387, NFE: 170
# average bpd: 2.655384063720703, NFE: 266
# average bpd: 2.655538558959961, NFE: 194
# average bpd: 2.6488728523254395, NFE: 188
# average bpd: 2.64168643951416, NFE: 212
# average bpd: 2.640761137008667, NFE: 176
# average bpd: 2.637655735015869, NFE: 200
# average bpd: 2.636284828186035, NFE: 194
# average bpd: 2.630784034729004, NFE: 170
# average bpd: 2.6273317337036133, NFE: 176
# average bpd: 2.62226939201355, NFE: 170
# average bpd: 2.6275405883789062, NFE: 194
# average bpd: 2.627372980117798, NFE: 230
# average bpd: 2.630794048309326, NFE: 176
# average bpd: 2.6335268020629883, NFE: 200
# average bpd: 2.6309618949890137, NFE: 188
# average bpd: 2.6293623447418213, NFE: 224
# average bpd: 2.6247851848602295, NFE: 278
# average bpd: 2.6311140060424805, NFE: 206
# average bpd: 2.6284213066101074, NFE: 182
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 8>()
#      10 img = torch.tensor(img).permute(0, 3, 1, 2).to(config.device)
#      11 img = scaler(img)
# ---> 12 bpd, z, nfe = likelihood_fn(score_model, img)
#      13 bpds.extend(bpd)
#      14 print(f"average bpd: {torch.tensor(bpds).mean().item()}, NFE: {nfe}")
#
# File ~/research_spring22/SBGM/score_sde_pytorch/likelihood.py:99, in get_likelihood_fn.<locals>.likelihood_fn(model, data)
#      96   return np.concatenate([drift, logp_grad], axis=0)
#      98 init = np.concatenate([mutils.to_flattened_numpy(data), np.zeros((shape[0],))], axis=0)
# ---> 99 solution = integrate.solve_ivp(ode_func, (eps, sde.T), init, rtol=rtol, atol=atol, method=method)
#     100 nfe = solution.nfev
#     101 zp = solution.y[:, -1]
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/scipy/integrate/_ivp/ivp.py:580, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     578 status = None
#     579 while status is None:
# --> 580     message = solver.step()
#     582     if solver.status == 'finished':
#     583         status = 0
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/scipy/integrate/_ivp/base.py:181, in OdeSolver.step(self)
#     179 else:
#     180     t = self.t
# --> 181     success, message = self._step_impl()
#     183     if not success:
#     184         self.status = 'failed'
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/scipy/integrate/_ivp/rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/scipy/integrate/_ivp/rk.py:64, in rk_step(fun, t, y, f, h, A, B, C, K)
#      62 for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63     dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64     K[s] = fun(t + c * h, y + dy)
#      66 y_new = y + h * np.dot(K[:-1].T, B)
#      67 f_new = fun(t + h, y_new)
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/scipy/integrate/_ivp/base.py:138, in OdeSolver.__init__.<locals>.fun(t, y)
#     136 def fun(t, y):
#     137     self.nfev += 1
# --> 138     return self.fun_single(t, y)
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/scipy/integrate/_ivp/base.py:20, in check_arguments.<locals>.fun_wrapped(t, y)
#      19 def fun_wrapped(t, y):
# ---> 20     return np.asarray(fun(t, y), dtype=dtype)
#
# File ~/research_spring22/SBGM/score_sde_pytorch/likelihood.py:94, in get_likelihood_fn.<locals>.likelihood_fn.<locals>.ode_func(t, x)
#      92 sample = mutils.from_flattened_numpy(x[:-shape[0]], shape).to(data.device).type(torch.float32)
#      93 vec_t = torch.ones(sample.shape[0], device=sample.device) * t
# ---> 94 drift = mutils.to_flattened_numpy(drift_fn(model, sample, vec_t))
#      95 logp_grad = mutils.to_flattened_numpy(div_fn(model, sample, vec_t, epsilon))
#      96 return np.concatenate([drift, logp_grad], axis=0)
#
# File ~/research_spring22/SBGM/score_sde_pytorch/likelihood.py:64, in get_likelihood_fn.<locals>.drift_fn(model, x, t)
#      62 # Probability flow ODE is a special case of Reverse SDE
#      63 rsde = sde.reverse(score_fn, probability_flow=True)
# ---> 64 return rsde.sde(x, t)[0]
#
# File ~/research_spring22/SBGM/score_sde_pytorch/sde_lib.py:96, in SDE.reverse.<locals>.RSDE.sde(self, x, t)
#      94 """Create the drift and diffusion functions for the reverse SDE/ODE."""
#      95 drift, diffusion = sde_fn(x, t)
# ---> 96 score = score_fn(x, t)
#      97 drift = drift - diffusion[:, None, None, None] ** 2 * score * (0.5 if self.probability_flow else 1.)
#      98 # Set the diffusion function to zero for ODEs.
#
# File ~/research_spring22/SBGM/score_sde_pytorch/models/utils.py:172, in get_score_fn.<locals>.score_fn(x, t)
#     169   labels *= sde.N - 1
#     170   labels = torch.round(labels).long()
# --> 172 score = model_fn(x, labels)
#     173 return score
#
# File ~/research_spring22/SBGM/score_sde_pytorch/models/utils.py:121, in get_model_fn.<locals>.model_fn(x, labels)
#     119 if not train:
#     120   model.eval()
# --> 121   return model(x, labels)
#     122 else:
#     123   model.train()
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/parallel/data_parallel.py:166, in DataParallel.forward(self, *inputs, **kwargs)
#     163     kwargs = ({},)
#     165 if len(self.device_ids) == 1:
# --> 166     return self.module(*inputs[0], **kwargs[0])
#     167 replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     168 outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/research_spring22/SBGM/score_sde_pytorch/models/ncsnpp.py:286, in NCSNpp.forward(self, x, time_cond)
#     284   m_idx += 1
#     285 else:
# --> 286   h = modules[m_idx](hs[-1], temb)
#     287   m_idx += 1
#     289 if self.progressive_input == 'input_skip':
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/research_spring22/SBGM/score_sde_pytorch/models/layerspp.py:254, in ResnetBlockBigGANpp.forward(self, x, temb)
#     252 elif self.down:
#     253   if self.fir:
# --> 254     h = up_or_down_sampling.downsample_2d(h, self.fir_kernel, factor=2)
#     255     x = up_or_down_sampling.downsample_2d(x, self.fir_kernel, factor=2)
#     256   else:
#
# File ~/research_spring22/SBGM/score_sde_pytorch/models/up_or_down_sampling.py:256, in downsample_2d(x, k, factor, gain)
#     254 k = _setup_kernel(k) * gain
#     255 p = k.shape[0] - factor
# --> 256 return upfirdn2d(x, torch.tensor(k, device=x.device),
#     257                  down=factor, pad=((p + 1) // 2, p // 2))
#
# KeyboardInterrupt:

# %%
#@title Representations
train_ds, eval_ds, _ = datasets.get_dataset(config, uniform_dequantization=False, evaluation=True)
eval_batch = next(iter(eval_ds))
eval_images = eval_batch['image']._numpy()
shape = (batch_size, 3, 256, 256)

likelihood_fn = likelihood.get_likelihood_fn(sde, inverse_scaler, eps=1e-5)
sampling_fn = sampling.get_ode_sampler(sde, shape, inverse_scaler,
                                       denoise=True, eps=sampling_eps, device=config.device)

plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
plt.axis('off')
plt.imshow(image_grid(eval_images))
plt.title('Original images')

# eval_images = torch.from_numpy(eval_images).permute(0, 3, 1, 2).to(config.device)
eval_images = torch.from_numpy(eval_images).to(config.device)
_, latent_z, _ = likelihood_fn(score_model, scaler(eval_images))

x, nfe = sampling_fn(score_model, latent_z)

# x = x.permute(0, 2, 3, 1).cpu().numpy()
x = x.cpu().numpy()
plt.subplot(1, 2, 2)
plt.axis('off')
plt.imshow(image_grid(x))
plt.title('Reconstructed images')
# Out:
# 2022-04-26 01:58:42.806037: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-04-26 01:58:42.810181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:3e:00.0 name: NVIDIA Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-04-26 01:58:42.810334: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-04-26 01:58:42.948323: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-04-26 01:58:42.948548: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-04-26 01:58:42.999559: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-04-26 01:58:43.039891: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-04-26 01:58:43.083136: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-04-26 01:58:43.124529: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-04-26 01:58:43.137526: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-04-26 01:58:43.153084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-04-26 01:58:43.429554: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-26 01:58:43.437816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:3e:00.0 name: NVIDIA Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-04-26 01:58:43.445541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-04-26 01:58:43.456158: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-04-26 01:58:43.457338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-26 01:58:43.457365: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2022-04-26 01:58:43.457383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2022-04-26 01:58:43.470672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 25725 MB memory) -> physical GPU (device: 0, name: NVIDIA Tesla V100-SXM2-32GB, pci bus id: 0000:3e:00.0, compute capability: 7.0)
# 2022-04-26 01:58:43.831145: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-04-26 01:58:43.833049: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2400000000 Hz
# 256
# 3
# 2
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 256
# 3
# 2
# Text(0.5, 1.0, 'Reconstructed images')

# %% [markdown]
# # Controllable generation
#
# Several demonstrations on how to solve inverse problems with our SDE framework.
#
# Recommended settings
#
# | dataset | SDE | predictor | corrector | snr | n_steps |
# |:----:|:----:|:----------:|:--------:|:---:|:----:|
# |CIFAR-10 | VE | ReverseDiffusionPredictor | LangevinCorrector | 0.16| 1|
# |CIFAR-10 | VP | EulerMaruyamaPredictor | None | - | - |
# |CIFAR-10 | subVP| EulerMaruyamaPredictor | None | - | - |
# | LSUN/CelebA-HQ/FFHQ 256px | VE | ReverseDiffusionPredictor | LangevinCorrector | 0.075 | 1 |
# | FFHQ 1024px | VE | ReverseDiffusionPredictor | LangevinCorrector | 0.15| 1 |

# %%
#@title PC inpainting
train_ds, eval_ds, _ = datasets.get_dataset(config)
eval_iter = iter(eval_ds)
bpds = []

predictor = ReverseDiffusionPredictor #@param ["EulerMaruyamaPredictor", "AncestralSamplingPredictor", "ReverseDiffusionPredictor", "None"] {"type": "raw"}
corrector = LangevinCorrector #@param ["LangevinCorrector", "AnnealedLangevinDynamics", "None"] {"type": "raw"}
snr = 0.075 #@param {"type": "number"}
n_steps = 1 #@param {"type": "integer"}
probability_flow = False #@param {"type": "boolean"}

pc_inpainter = controllable_generation.get_pc_inpainter(sde,
                                                        predictor, corrector,
                                                        inverse_scaler,
                                                        snr=snr,
                                                        n_steps=n_steps,
                                                        probability_flow=probability_flow,
                                                        continuous=config.training.continuous,
                                                        denoise=True)
batch = next(eval_iter)
img = batch['image']._numpy()
# img = torch.from_numpy(img).permute(0, 3, 1, 2).to(config.device)
img = torch.from_numpy(img).to(config.device)
show_samples(img)

mask = torch.ones_like(img)
mask[:, :, :, 128:] = 0.
show_samples(img * mask)


x = pc_inpainter(score_model, scaler(img), mask)
show_samples(x)
# Out:
# 256
# 3
# 2
# 256
# 3
# 2
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [11], in <cell line: 31>()
#      27 mask[:, :, :, 128:] = 0.
#      28 show_samples(img * mask)
# ---> 31 x = pc_inpainter(score_model, scaler(img), mask)
#      32 show_samples(x)
#
# File ~/research_spring22/SBGM/score_sde_pytorch/controllable_generation.py:77, in get_pc_inpainter.<locals>.pc_inpainter(model, data, mask)
#      75 for i in range(sde.N):
#      76   t = timesteps[i]
# ---> 77   x, x_mean = corrector_inpaint_update_fn(model, data, mask, x, t)
#      78   x, x_mean = projector_inpaint_update_fn(model, data, mask, x, t)
#      80 return inverse_scaler(x_mean if denoise else x)
#
# File ~/research_spring22/SBGM/score_sde_pytorch/controllable_generation.py:47, in get_pc_inpainter.<locals>.get_inpaint_update_fn.<locals>.inpaint_update_fn(model, data, mask, x, t)
#      45 with torch.no_grad():
#      46   vec_t = torch.ones(data.shape[0], device=data.device) * t
# ---> 47   x, x_mean = update_fn(x, vec_t, model=model)
#      48   masked_data_mean, std = sde.marginal_prob(data, vec_t)
#      49   masked_data = masked_data_mean + torch.randn_like(x) * std[:, None, None, None]
#
# File ~/research_spring22/SBGM/score_sde_pytorch/sampling.py:352, in shared_corrector_update_fn(x, t, sde, model, corrector, continuous, snr, n_steps)
#     350 else:
#     351   corrector_obj = corrector(sde, score_fn, snr, n_steps)
# --> 352 return corrector_obj.update_fn(x, t)
#
# File ~/research_spring22/SBGM/score_sde_pytorch/sampling.py:274, in LangevinCorrector.update_fn(self, x, t)
#     271   alpha = torch.ones_like(t)
#     273 for i in range(n_steps):
# --> 274   grad = score_fn(x, t)
#     275   noise = torch.randn_like(x)
#     276   grad_norm = torch.norm(grad.reshape(grad.shape[0], -1), dim=-1).mean()
#
# File ~/research_spring22/SBGM/score_sde_pytorch/models/utils.py:172, in get_score_fn.<locals>.score_fn(x, t)
#     169   labels *= sde.N - 1
#     170   labels = torch.round(labels).long()
# --> 172 score = model_fn(x, labels)
#     173 return score
#
# File ~/research_spring22/SBGM/score_sde_pytorch/models/utils.py:121, in get_model_fn.<locals>.model_fn(x, labels)
#     119 if not train:
#     120   model.eval()
# --> 121   return model(x, labels)
#     122 else:
#     123   model.train()
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/parallel/data_parallel.py:166, in DataParallel.forward(self, *inputs, **kwargs)
#     163     kwargs = ({},)
#     165 if len(self.device_ids) == 1:
# --> 166     return self.module(*inputs[0], **kwargs[0])
#     167 replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     168 outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/research_spring22/SBGM/score_sde_pytorch/models/ncsnpp.py:268, in NCSNpp.forward(self, x, time_cond)
#     265 if self.progressive_input != 'none':
#     266   input_pyramid = x
# --> 268 hs = [modules[m_idx](x)]
#     269 m_idx += 1
#     270 for i_level in range(self.num_resolutions):
#     271   # Residual blocks for this resolution
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/modules/conv.py:447, in Conv2d.forward(self, input)
#     446 def forward(self, input: Tensor) -> Tensor:
# --> 447     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/torch/nn/modules/conv.py:443, in Conv2d._conv_forward(self, input, weight, bias)
#     439 if self.padding_mode != 'zeros':
#     440     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     441                     weight, bias, self.stride,
#     442                     _pair(0), self.dilation, self.groups)
# --> 443 return F.conv2d(input, weight, bias, self.stride,
#     444                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [128, 3, 3, 3], expected input[4, 256, 3, 256] to have 3 channels, but got 256 channels instead

# %%
#@title PC colorizer
train_ds, eval_ds, _ = datasets.get_dataset(config)
eval_iter = iter(eval_ds)
bpds = []

predictor = ReverseDiffusionPredictor #@param ["EulerMaruyamaPredictor", "AncestralSamplingPredictor", "ReverseDiffusionPredictor", "None"] {"type": "raw"}
corrector = LangevinCorrector #@param ["LangevinCorrector", "AnnealedLangevinDynamics", "None"] {"type": "raw"}
snr = 0.16 #@param {"type": "number"}
n_steps = 1 #@param {"type": "integer"}
probability_flow = False #@param {"type": "boolean"}

batch = next(eval_iter)
img = batch['image']._numpy()
img = torch.from_numpy(img).permute(0, 3, 1, 2).to(config.device)
show_samples(img)
gray_scale_img = torch.mean(img, dim=1, keepdims=True).repeat(1, 3, 1, 1)
show_samples(gray_scale_img)
gray_scale_img = scaler(gray_scale_img)
pc_colorizer = controllable_generation.get_pc_colorizer(
    sde, predictor, corrector, inverse_scaler,
    snr=snr, n_steps=n_steps, probability_flow=probability_flow,
    continuous=config.training.continuous, denoise=True
)
x = pc_colorizer(score_model, gray_scale_img)

show_samples(x)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Input In [14], in <cell line: 12>()
#       9 n_steps = 1 #@param {"type": "integer"}
#      10 probability_flow = False #@param {"type": "boolean"}
# ---> 12 batch = next(eval_iter)
#      13 img = batch['image']._numpy()
#      14 img = torch.from_numpy(img).permute(0, 3, 1, 2).to(config.device)
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:761, in OwnedIterator.__next__(self)
#     759 def __next__(self):
#     760   try:
# --> 761     return self._next_internal()
#     762   except errors.OutOfRangeError:
#     763     raise StopIteration
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:744, in OwnedIterator._next_internal(self)
#     741 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     742 # to communicate that there is no more data to iterate over.
#     743 with context.execution_mode(context.SYNC):
# --> 744   ret = gen_dataset_ops.iterator_get_next(
#     745       self._iterator_resource,
#     746       output_types=self._flat_output_types,
#     747       output_shapes=self._flat_output_shapes)
#     749   try:
#     750     # Fast path for the case `self._structure` is not a nested structure.
#     751     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/tensorflow/python/ops/gen_dataset_ops.py:2728, in iterator_get_next(iterator, output_types, output_shapes, name)
#    2726   return _result
#    2727 except _core._NotOkStatusException as e:
# -> 2728   _ops.raise_from_not_ok_status(e, name)
#    2729 except _core._FallbackException:
#    2730   pass
#
# File ~/.conda/envs/SBGMv2/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:6897, in raise_from_not_ok_status(e, name)
#    6895 message = e.message + (" name: " + name if name is not None else "")
#    6896 # pylint: disable=protected-access
# -> 6897 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# NotFoundError: /home/yangsong/ncsc/celebahq/r08.tfrecords; No such file or directory [Op:IteratorGetNext]

# %% [markdown]
# ## Class-conditional generation

# %% [markdown]
# Check out the [class-conditional generation section](https://colab.research.google.com/drive/1dRR_0gNRmfLtPavX2APzUggBuXyjWW55#scrollTo=HiYRNB-Wk329&line=3&uniqifier=1) in our [JAX demo](https://colab.research.google.com/drive/1dRR_0gNRmfLtPavX2APzUggBuXyjWW55?usp=sharing)
